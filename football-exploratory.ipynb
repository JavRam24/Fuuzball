# %% [markdown]
# # NFL Football Dataset

# %%
import pandas as pd
import nfl_data_py as nfl

# %%
cols = list(nfl.see_pbp_cols())

# %% [markdown]
# # Things to Find
# * Correlation Matrix for Target Y: Outcome of Game W/L
#     * Potential other Ys: Specific Player Stats
#     * Features:
#         * Player stats from PbP (Play By Play)
#         * Outcome referenced in Feature set by PbP (For W/L: Y)
# * PCA Analysis:
#     * Target Prediction at 95%

# %%
dataset = nfl.import_pbp_data([2024, 2023, 2022, 2021], downcast=True, cache=False, alt_path=None)
# Out:
# 2024 done.
# 2023 done.
# 2022 done.
# 2021 done.
# Downcasting floats.

# %%
dataset.head()
# Out:
#    play_id          game_id old_game_id home_team away_team season_type  week  \
# 0      1.0  2024_01_ARI_BUF  2024090801       BUF       ARI         REG     1
# 1     40.0  2024_01_ARI_BUF  2024090801       BUF       ARI         REG     1
# 2     61.0  2024_01_ARI_BUF  2024090801       BUF       ARI         REG     1
# 3     83.0  2024_01_ARI_BUF  2024090801       BUF       ARI         REG     1
# 4    108.0  2024_01_ARI_BUF  2024090801       BUF       ARI         REG     1
#
#   posteam posteam_type defteam  ... offense_players  defense_players  \
# 0    None         None    None  ...             NaN              NaN
# 1     ARI         away     BUF  ...             NaN              NaN
# 2     ARI         away     BUF  ...             NaN              NaN
# 3     ARI         away     BUF  ...             NaN              NaN
# 4     ARI         away     BUF  ...             NaN              NaN
#
#   n_offense  n_defense  ngs_air_yards  time_to_throw was_pressure  route  \
# ...
